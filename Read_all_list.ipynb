# %%
import csv
import pandas as pd

class read_all_list():
        
    # Extract Education Details from PDF Here all Functions for Keywords. Keywords for Educational Degree, College etc.
    #def create_segments()
    def read_csv(self,input_file):
        file = open(input_file, 'r')
        reader = csv.reader(file)
        return reader

    def get_keywords(self,dir_path,file_name):
        reader = self.read_csv(dir_path + file_name)
        keywords = []
        for row in reader:
            keywords.append(row[0])
        return keywords

    def get_qualification_word_list(self,dir_path):
        file_name = "qualification_degree_list.csv"
        reader = self.read_csv(dir_path+file_name)
        qualification_word_dict = {}
        abbr_list = []
        degree_list = []
        for row in reader:
            abbr_list.append(row[0])
            degree_list.append(row[1])
            qualification_word_dict[row[0]] = row[1]
        return qualification_word_dict, abbr_list, degree_list
    
    def search_keyword(text, keyword_list):
        for word in keyword_list:
            word = str(word)
            if word.title() in text or word.upper() in text or word.capitalize() in text:
                return True
        return False
    '''
    def get_university_word_list(self,dir_path):
        file_name = "university.csv"
        reader = self.read_csv(dir_path + file_name)
        university_word_dict = {}
        for row in reader:
            value = [row[2], row[3], row[4], row[5]]
            university_word_dict[row[1]] = value
        return university_word_dict

    
    
    def get_major_word_list(self,dir_path):
        file_name = "educational_major.csv"
        reader = self.read_csv(dir_path + file_name)
        major_list = []
        for row in reader:
            major_list.append(row[0])
        return major_list

    def company_name_list(self,dir_path):
        file_name = "new_companies_list.csv"
        reader = self.read_csv(dir_path + file_name)
        company_words_list = []
        for row in reader:
            company_words_list.append(row[0])
        return company_words_list

    def position_title_list(self,dir_path):
        file_name = 'uk_position_title.csv'
        reader = pd.read_csv(dir_path + file_name)
        job_title_list = []
        for i in range(0,len(reader)):
            job_title_list.append(reader['Position'].iloc[i])
        return job_title_list

    def person_name_list(self,dir_path):
        file_name = 'uk_name.csv'
        reader = pd.read_csv(dir_path + file_name)
        name_list = []
        for i in range(0,len(reader)):
            name_list.append(reader['firstname'].iloc[i].lower())
        return name_list

    def skill_list(self,dir_path):
        file_name = 'skills.csv'
        reader = pd.read_csv(dir_path + file_name)
        skills_list = []
        print(reader['subcategory'].iloc[0])
        for i in range(0,len(reader)):
            skills_list.append(reader['subcategory'].iloc[i])
        return skills_list
    '''
