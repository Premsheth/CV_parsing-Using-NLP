# %%
import nbimporter
import import_ipynb
from importlib import reload
import cv_parsing_main_class as main
import MySQLdb
import MySQLdb.cursors
import requests
import pandas as pd
import numpy as np

reload(main)

import os

import time
start_time = time.time()



path = '/Users/imac086/Documents/premal/projects_Quix/CV_parsing/CV_parsing_API_code/few_cvs/'
for filename in os.listdir(path):
    #try:
    print(filename)
    fn = filename.split(".")[1]
    print(fn)
    exten = ['DOC','doc','DOCX','docx','PDF','pdf']

    if fn in exten:
        """SQL Query used"""
        details = main.parse_all_details(filename,path)
        d = details.info()

        if not d['name']:
            d['name'].append(None)
        if not d['email']:
            d['email'].append(None)
        if not d['phone']:
            d['phone'].append([None])
        if not d['zipcode']:
            d['zipcode'].append(None)
        if not d['year']:
            y = [None,None]
            d['year'].append(y)
        if not d['university']:
            d['university'].append(None)
        if not d['degree']:
            d['degree'].append(None)
        if not d['major']:
            d['major'].append(None)
        if not d['Date']:
            y = {'start_year':None,'end_year':None}
            d['Date'].append(y)
        if not d['Job_Title']:
            d['Job_Title'].append(None)
        if not d['company']:
            d['company'].append(None)
        #if not d['skill_keyword']:
        #    d['skill_keyword'].append(None)

        print("===== Final Output ===========")
        print(d)
        
        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Importing Jupyter notebook from cv_parsing_main_class.ipynb
# .DS_Store
# DS_Store
# Zubin Bhedwar MARKETING MGR.doc
# doc
# ['', 'Zubin Bhedwar          Zubin.bhedwar@sky.com 07734537831', '11 Imperial Court, Imperial Drive, Harrow, HA2 7HU', 'I am a marketing professional with experience in a wide range of marketing', 'skills developed over a period of eight years within a world-class consumer', 'brand. My main attributes are that I am reliable and hard working, and my', 'love for marketing is actually a love for creativity. It is in my nature to', 'think outside the box, and go out of my way at times in order to not do', 'something in the conventional manner.', 'WORK EXPERIENCE (PROFESSIONAL)', 'The London Dungeon- Feb 2009  April 2009', 'Job Title:       Marketing Manager', 'Key Roles and Responsibilities:', 'Create, maintain and monitor volume driven promotions.', 'Work with the PR Manager to gain more exposure for the business.', 'Evaluate demographics of the business.', 'Monitor trends and identify key strength and weaknesses in order to', 'help the business achieve visitor number and financial targets.', 'Target consumers in order to push secondary spends.', 'Analyse customer service using KPIs.', 'Copy writing and proof reading of various PR and promotional', 'materials.', 'Cobra Beer Ltd- Aug 2001- December 2008', 'Job Titles:      Employee Engagement Manager', 'Sponsorship and Events Manager', 'Cobra Foundation Manger', 'Promotions Manager', 'Marketing Executive', 'Intern', 'Key Roles and Responsibilities:', 'Manage temporary and part-time staff', 'Promotions', 'Design and Execute Creatives and incentives to increase rate  of', 'sale.', 'Provide backup literature to assist sales and telesales teams.', 'Target both the trade and  end  consumers  through  direct  mail', 'campaigns.', 'Deal with redemptions for the promotion.', 'Analyse redemption rates both during and  after  the  promotion,', 'in order to determine its rate of success.', 'Point of Sale and Promotion', 'Sourcing POS, promotional material and services.', 'Negotiate best terms and conditions for the company.', 'Quality  control-  ensured  the  quality  of  the  item/service', 'obtained meets pacific standards as this  reflects  directly  on', 'the brand and how it is perceived in the market place.', 'Interacting with different departments in order to  be  able  to', 'fulfil their needs, whilst synchronizing requirements across all', 'departments  in  order  to  help  keep  things  cost  and   time', 'effective.', 'Generating relationships with the right suppliers  in  order  to', 'achieve the best results on an ongoing basis.', 'Enforcing budget controls across the board.', 'Internal and external tracking  and  monitoring  of  promotional', 'items.', 'Maintain stock controls.', 'Setting certain standards and meeting expectations.', 'Work closely with both in-house and external teams in  order  to', 'develop the best creative for the promotion.', 'Work  closely  with  sales  in  determining  the  mechanics  of', 'promotions.', 'Communicate all promotions to the target audience using  various', 'forms of direct marketing.', 'Work closely with the heads of offices  in  other  countries  to', 'provide both generic POS to be used across a global  basis,  and', 'specific POS tailored for their individual markets.', 'PR Responsibilities previously held', 'Sort through and distribute press cuttings.', 'Dealing with PR agencies.', 'Copy writing and proofreading various marketing materials.', 'Exhibitions- Trade & Consumer Shows/ Festivals & Melas', 'Work with other partners on joint projects.', 'Liase with  organizers,  in  order  to  negotiate  costs,  stand', 'space, etc.', 'Supervise contractors and help with  build  and  set-up  of  the', 'stand.', 'Participate in all visible and behind the scenes roles  involved', 'in running the stand.', 'Overlook the overall running of the stand.', 'Managing staff on the stand.', 'Manage stock controls.', 'Handling money taken.', 'Allow  for  contingencies  and  deal  with  unforeseen  problems', 'during the show.', 'Establish and build relatio ...
# ['Zubin']
# Parse Name from DOC ====== ['Zubin']
# ()
# ()
# ()
# ()
# ()
# ()
# ({'university': 'Reading'},)
# Else statment
# ()
# ()
# ()
# ()
# ()
# =======work segment ==========
# ['WORK EXPERIENCE PROFESSIONAL', 'The London Dungeon Feb 2009  April 2009', 'Job Title       Marketing Manager', 'Key Roles and Responsibilities', 'Create maintain and monitor volume driven promotions', 'Work with the PR Manager to gain more exposure for the business', 'Evaluate demographics of the business', 'Monitor trends and identify key strength and weaknesses in order to', 'help the business achieve visitor number and financial targets', 'Target consumers in order to push secondary spends', 'Analyse customer service using KPIs', 'Copy writing and proof reading of various PR and promotional', 'materials', 'Cobra Beer Ltd Aug 2001 December 2008', 'Job Titles      Employee Engagement Manager', 'Sponsorship and Events Manager', 'Cobra Foundation Manger', 'Promotions Manager', 'Marketing Executive', 'Intern', 'Key Roles and Responsibilities', 'Manage temporary and parttime staff', 'Promotions', 'Design and Execute Creatives and incentives to increase rate  of', 'sale', 'Provide backup literature to assist sales and telesales teams', 'Target both the trade and  end  consumers  through  direct  mail', 'campaigns', 'Deal with redemptions for the promotion', 'Analyse redemption rates both during and  after  the  promotion', 'in order to determine its rate of success', 'Point of Sale and Promotion', 'Sourcing POS promotional material and services', 'Negotiate best terms and conditions for the company', 'Quality  control  ensured  the  quality  of  the  itemservice', 'obtained meets pacific standards as this  reflects  directly  on', 'the brand and how it is perceived in the market place', 'Interacting with different departments in order to  be  able  to', 'fulfil their needs whilst synchronizing requirements across all', 'departments  in  order  to  help  keep  things  cost  and   time', 'effective', 'Generating relationships with the right suppliers  in  order  to', 'achieve the best results on an ongoing basis', 'Enforcing budget controls across the board', 'Internal and external tracking  and  monitoring  of  promotional', 'items', 'Maintain stock controls', 'Setting certain standards and meeting expectations', 'Work closely with both inhouse and external teams in  order  to', 'develop the best creative for the promotion', 'Work  closely  with  sales  in  determining  the  mechanics  of', 'promotions', 'Communicate all promotions to the target audience using  various', 'forms of direct marketing', 'Work closely with the heads of offices  in  other  countries  to', 'provide both generic POS to be used across a global  basis  and', 'specific POS tailored for their individual markets', 'PR Responsibilities previously held', 'Sort through and distribute press cuttings', 'Dealing with PR agencies', 'Copy writing and proofreading various marketing materials', 'Exhibitions Trade  Consumer Shows Festivals  Melas', 'Work with other partners on joint projects', 'Liase with  organizers  in  order  to  negotiate  costs  stand', 'space etc', 'Supervise contractors and help with  build  and  setup  of  the', 'stand', 'Participate in all visible and behind the scenes roles  involved', 'in running the stand', 'Overlook the overall running of the stand', 'Managing staff on the stand', 'Manage stock controls', 'Handling money taken', 'Allow  for  contingencies  and  deal  with  unforeseen  problems', 'during the show', 'Establish and build relationships with other  companies  in  order  to', 'help both the company and brand establish and grow in certain areas', 'Communication', 'Ability to communicate between all departments across the  board', 'and at all levels of senioritymanagement', 'Sort through and distribute press cuttings that are relevant  to', 'the business both internally and externally', 'Sponsorship', 'Source and propose sponsorships which will benefit the brand', 'Assess sponsorship requests in terms of feasibility and  how  it', 'benefits both the company and brand', 'Negotiate costs off and levels coverage we  will  receive  fro ...
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# --- 423.1875340938568 seconds ---
# {'cv_name': 'Zubin Bhedwar MARKETING MGR.doc', 'name': ['Zubin'], 'email': ['Zubin.bhedwar@sky.com'], 'phone': [['07734537831'], ['1997-2001        '], ['1994-1997        '], ['1990-1994        ']], 'zipcode': ['HA2 7HU'], 'other_links': [], 'year': [], 'university': ['Reading'], 'degree': [], 'major': [], 'Date': [{'start_year': 'Feb 2009', 'end_year': 'April 2009'}, {'start_year': 'Aug 2001', 'end_year': 'December 2008'}, {'start_year': 'Feb 2009', 'end_year': 'April 2009'}], 'Job_Title': ['Marketing Manager', 'Marketing Manager', 'Marketing Executive', 'Marketing Executive', 'Marketing Manager'], 'company': ['The London Dungeon', 'ER LIMITED', 'THE COBRA FOUNDATION'], 'skills': ['Marketing', 'Sales', 'Customer Service', 'Branding', 'Research', 'Writing'], 'edu_keyword': ['EDUCATIONAL ACHIEVEMENTS', 'BA Marketing', 'HND Business & Marketing', 'GNVQ Advanced Business & Marketing', 'GNVQ Intermediate Business', 'PERSONAL INTERESTS', 'PERSONAL INTERESTS', 'films, and going out to bars and restaurants.', 'Over the years I have developed a love for food, which in turn has led to', 'me experimenting in the kitchen and along with beating the hell out of my', 'punch bag has become my main output for relieving stress.', ''], 'work_keyword': ['WORK EXPERIENCE PROFESSIONAL', 'Job Title       Marketing Manager', 'Key Roles and Responsibilities', 'Create maintain and monitor volume driven promotions', 'Work with the PR Manager to gain more exposure for the business', 'Evaluate demographics of the business', 'Monitor trends and identify key strength and weaknesses in order to', 'help the business achieve visitor number and financial targets', 'Target consumers in order to push secondary spends', 'Analyse customer service using KPIs', 'Copy writing and proof reading of various PR and promotional', 'materials', 'Job Titles      Employee Engagement Manager', 'Sponsorship and Events Manager', 'Cobra Foundation Manger', 'Promotions Manager', 'Marketing Executive', 'Intern', 'Key Roles and Responsibilities', 'Manage temporary and parttime staff', 'Promotions', 'Design and Execute Creatives and incentives to increase rate  of', 'sale', 'Provide backup literature to assist sales and telesales teams', 'Target both the trade and  end  consumers  through  direct  mail', 'campaigns', 'Deal with redemptions for the promotion', 'Analyse redemption rates both during and  after  the  promotion', 'in order to determine its rate of success', 'Point of Sale and Promotion', 'Sourcing POS promotional material and services', 'Negotiate best terms and conditions for the company', 'Quality  control  ensured  the  quality  of  the  itemservice', 'obtained meets pacific standards as this  reflects  directly  on', 'the brand and how it is perceived in the market place', 'Interacting with different departments in order to  be  able  to', 'fulfil their needs whilst synchronizing requirements across all', 'departments  in  order  to  help  keep  things  cost  and   time', 'effective', 'Generating relationships with the right suppliers  in  order  to', 'achieve the best results on an ongoing basis', 'Enforcing budget controls across the board', 'Internal and external tracking  and  monitoring  of  promotional', 'items', 'Maintain stock controls', 'Setting certain standards and meeting expectations', 'Work closely with both inhouse and external teams in  order  to', 'develop the best creative for the promotion', 'Work  closely  with  sales  in  determining  the  mechanics  of', 'promotions', 'Communicate all promotions to the target audience using  various', 'forms of direct marketing', 'Work closely with the heads of offices  in  other  countries  to', 'provide both generic POS to be used across a global  basis  and', 'specific POS tailored for their individual markets', 'PR Responsibilities previously held', 'Sort through and distribute press cuttings', 'Dealing with PR agencies', 'Copy writing and proofreading various marketing materials', 'Exhibitions Trade  Consume ...
# ===== Final Output ===========
# {'cv_name': 'Zubin Bhedwar MARKETING MGR.doc', 'name': ['Zubin'], 'email': ['Zubin.bhedwar@sky.com'], 'phone': [['07734537831'], ['1997-2001        '], ['1994-1997        '], ['1990-1994        ']], 'zipcode': ['HA2 7HU'], 'other_links': [], 'year': [[None, None]], 'university': ['Reading'], 'degree': [None], 'major': [None], 'Date': [{'start_year': 'Feb 2009', 'end_year': 'April 2009'}, {'start_year': 'Aug 2001', 'end_year': 'December 2008'}, {'start_year': 'Feb 2009', 'end_year': 'April 2009'}], 'Job_Title': ['Marketing Manager', 'Marketing Manager', 'Marketing Executive', 'Marketing Executive', 'Marketing Manager'], 'company': ['The London Dungeon', 'ER LIMITED', 'THE COBRA FOUNDATION'], 'skills': ['Marketing', 'Sales', 'Customer Service', 'Branding', 'Research', 'Writing'], 'edu_keyword': ['EDUCATIONAL ACHIEVEMENTS', 'BA Marketing', 'HND Business & Marketing', 'GNVQ Advanced Business & Marketing', 'GNVQ Intermediate Business', 'PERSONAL INTERESTS', 'PERSONAL INTERESTS', 'films, and going out to bars and restaurants.', 'Over the years I have developed a love for food, which in turn has led to', 'me experimenting in the kitchen and along with beating the hell out of my', 'punch bag has become my main output for relieving stress.', ''], 'work_keyword': ['WORK EXPERIENCE PROFESSIONAL', 'Job Title       Marketing Manager', 'Key Roles and Responsibilities', 'Create maintain and monitor volume driven promotions', 'Work with the PR Manager to gain more exposure for the business', 'Evaluate demographics of the business', 'Monitor trends and identify key strength and weaknesses in order to', 'help the business achieve visitor number and financial targets', 'Target consumers in order to push secondary spends', 'Analyse customer service using KPIs', 'Copy writing and proof reading of various PR and promotional', 'materials', 'Job Titles      Employee Engagement Manager', 'Sponsorship and Events Manager', 'Cobra Foundation Manger', 'Promotions Manager', 'Marketing Executive', 'Intern', 'Key Roles and Responsibilities', 'Manage temporary and parttime staff', 'Promotions', 'Design and Execute Creatives and incentives to increase rate  of', 'sale', 'Provide backup literature to assist sales and telesales teams', 'Target both the trade and  end  consumers  through  direct  mail', 'campaigns', 'Deal with redemptions for the promotion', 'Analyse redemption rates both during and  after  the  promotion', 'in order to determine its rate of success', 'Point of Sale and Promotion', 'Sourcing POS promotional material and services', 'Negotiate best terms and conditions for the company', 'Quality  control  ensured  the  quality  of  the  itemservice', 'obtained meets pacific standards as this  reflects  directly  on', 'the brand and how it is perceived in the market place', 'Interacting with different departments in order to  be  able  to', 'fulfil their needs whilst synchronizing requirements across all', 'departments  in  order  to  help  keep  things  cost  and   time', 'effective', 'Generating relationships with the right suppliers  in  order  to', 'achieve the best results on an ongoing basis', 'Enforcing budget controls across the board', 'Internal and external tracking  and  monitoring  of  promotional', 'items', 'Maintain stock controls', 'Setting certain standards and meeting expectations', 'Work closely with both inhouse and external teams in  order  to', 'develop the best creative for the promotion', 'Work  closely  with  sales  in  determining  the  mechanics  of', 'promotions', 'Communicate all promotions to the target audience using  various', 'forms of direct marketing', 'Work closely with the heads of offices  in  other  countries  to', 'provide both generic POS to be used across a global  basis  and', 'specific POS tailored for their individual markets', 'PR Responsibilities previously held', 'Sort through and distribute press cuttings', 'Dealing with PR agencies', 'Copy writing and proofreading various marketing materials', 'Exhibi ...
# --- 424.04653811454773 seconds ---
# Zul Hassan CPW ONLINE COORDINATOR.doc
# doc
# ['', 'Profile:', 'Graduate  in  marketing  with  a  service  industry  background.  Worked  in', 'marketing  within  retail  and  publication,  handling  Direct  and   Online', 'communications. Adept at communicating effectively at all  levels.  A  team-', "player with a pro-active approach and ability to  multi-task  and  'muck-in'", 'when required with the tenacity to see projects through to completion', 'Key Achievements', 'Coordinated online content and distribution process within Escapade.', 'Researched on effective solutions for internal communication and', 'distribution process at Escapade.', 'Handled direct marketing of the Muslim Weekly newspaper: target', 'consumers via email, media packs, managed website content, and', 'assisted on catalogue production', "Instigated and project managed the Muslim Weekly's weekly e-", 'newsletter, providing a new revenue stream.', 'Liased with Sit Ups clients on order management and the resolution of', 'queries and escalations.', 'Key responsibilities include:', 'Marketing Communications', '- Assisted in graphic creation', '- PowerPoint creation', '- Monitor new web activities', '- Internet/Intranet publishing', '- PR Support', '- Content modification/research', '- Exhibition logistics', '- Event support', '- Occasional outbound telemarketing', 'Marketing Administration', '- Direct marketing organisation', '- Database inputting and reporting', '- Internet statistic reporting', '- Marcom reporting', '- Logistics (moving/packing internet orders, media packs)', 'Work Experience', 'May07-To Date         Web Coordinator', 'Carphonewarehouse, London', 'Maintaining the web content on the www.carphonewarehouse.com Key', 'responsibilities includes: -', 'Ensuring that all pricing, special offers and promotions on the', 'website are up to date, accurate and consistent with the commercial', 'direction.', 'Managing the day to day requests from the commercial and marketing', 'teams to deliver and achieve tight deadlines', 'Implementing offers and content - including uploading, testing,', 'quality assuring and trouble shooting online campaigns', 'Maintaining internal relationships with commercial, promotions,', 'creative and marketing departments', 'Monitoring performance of offers and providing suggestion on future', 'offer setups.', 'Apr06-Apr07          Online Database Coordinator', 'Escapade Ltd, London', 'Managing the website content and assisting on the shop floor related tasks.', 'Key responsibilities include: -', 'Ensured all content on the website is accurate and updated and', 'modified accordingly.', 'Researched on possible web communication mediums, and identifying new', 'potential revenues.', 'Processed Internet orders and managing distribution within the given', 'period', 'Arranged goods from warehouse as required and sorted POS orders.', 'Assisted the in-house team to acquire print material and compilation', 'of catalogues.', 'Coordinated with in-house team members on related issues such as', 'ensuring all promotions, special offers, products, tariffs, pricing is', 'accurate and delivered to schedule', 'Identifed and proactively managing issues on the shop floor.', 'Nov05Mar06                      Marketing & Communications Coordinator', 'Muslim Media Ltd, London', 'Handle the marketing communication process of the weekly-distributed', 'newspaper The Muslim Weekly. Key responsibilities included: -', 'Coordinated the communication process effectively; frequency and', 'target market.', 'Build brand awareness through various email shots and media packs', 'campaigns.', 'Implemented the publications weekly online newsletter, and email', 'database', 'Liaised with internal departments on the current promotions/offers.', 'Actively worked with the sales teams to obtain potential clients for', 'advertising', 'Handled the promotional activity during various exhibitions, events,', 'and road shows.', 'Maintain communication channels with university unions, libraries,', 'charities and advertising a ...
# ['Rad']
# Parse Name from DOC ====== ['Rad']
# ()
# ()
# ({'university': 'London'},)
# Else statment
# ()
# ()
# ({'university': 'Lincoln'},)
# Else statment
# ()
# ()
# ()
# ()
# ()
# ({'university': 'Reading'},)
# Else statment
# ()
# ()
# ()
# ()
# ({'university': 'London'},)
# Else statment
# ()
# =======work segment ==========
# ['Work Experience', 'May07To Date         Web Coordinator', 'Carphonewarehouse London', 'Maintaining the web content on the wwwcarphonewarehousecom Key', 'responsibilities includes ', 'Ensuring that all pricing special offers and promotions on the', 'website are up to date accurate and consistent with the commercial', 'direction', 'Managing the day to day requests from the commercial and marketing', 'teams to deliver and achieve tight deadlines', 'Implementing offers and content  including uploading testing', 'quality assuring and trouble shooting online campaigns', 'Maintaining internal relationships with commercial promotions', 'creative and marketing departments', 'Monitoring performance of offers and providing suggestion on future', 'offer setups', 'Apr06Apr07          Online Database Coordinator', 'Escapade Ltd London', 'Managing the website content and assisting on the shop floor related tasks', 'Key responsibilities include ', 'Ensured all content on the website is accurate and updated and', 'modified accordingly']
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# ----- Company name not in Sentence -----
# --- 72.75451493263245 seconds ---
# {'cv_name': 'Zul Hassan CPW ONLINE COORDINATOR.doc', 'name': ['Rad'], 'email': ['zulfiqarjh@yahoo.com'], 'phone': [['07969670714']], 'zipcode': ['ov05Ma', 'un04No', 'pr03De', 'NW2 4BW'], 'other_links': [], 'year': [], 'university': ['London', 'Lincoln', 'Reading', 'London'], 'degree': ['Business Administration'], 'major': [], 'Date': [], 'Job_Title': ['Web Coordinator', 'Online Database Coordinator', 'Online Database Coordinator', 'Online Database Coordinator', 'Web Coordinator'], 'company': ['Carphonewarehouse', 'Carphonewarehouse', 'Escapade Limited'], 'skills': ['Marketing', 'Web Content'], 'edu_keyword': ['Education', 'Jan04-Dec05Master of Business Administration in  American World      ', 'Jan04-Dec05Master of Business Administration in  American World      ', '                                                 Campus              ', 'Sep96-May00Bachelor of Business Administration   University of       ', 'Sep96-May00Bachelor of Business Administration   University of       ', '                                                 Humberside          ', 'Computer skills:', 'MS Office (Word, Excel, PowerPoint, Access, Publisher), MS Project, Lotus', 'Notes, Adobe Photoshop, Dreamweaver, Visual Basic, Remedy, and Internet', 'Interests:', 'Interests:', 'and newspapers & enjoy travelling', '-----------------------', 'ZULFIQAR HASSAN', '26 Landau House, Chatsworth Rd,', '26 Landau House, Chatsworth Rd,', ''], 'work_keyword': ['Work Experience', 'May07To Date         Web Coordinator', 'May07To Date         Web Coordinator', 'Carphonewarehouse London', 'responsibilities includes ', 'Ensuring that all pricing special offers and promotions on the', 'website are up to date accurate and consistent with the commercial', 'direction', 'Managing the day to day requests from the commercial and marketing', 'teams to deliver and achieve tight deadlines', 'Implementing offers and content  including uploading testing', 'quality assuring and trouble shooting online campaigns', 'Maintaining internal relationships with commercial promotions', 'creative and marketing departments', 'Monitoring performance of offers and providing suggestion on future', 'offer setups', 'Apr06Apr07          Online Database Coordinator', 'Apr06Apr07          Online Database Coordinator', 'Managing the website content and assisting on the shop floor related tasks', 'Key responsibilities include ', 'Ensured all content on the website is accurate and updated and', 'modified accordingly']}
# ===== Final Output ===========
# {'cv_name': 'Zul Hassan CPW ONLINE COORDINATOR.doc', 'name': ['Rad'], 'email': ['zulfiqarjh@yahoo.com'], 'phone': [['07969670714']], 'zipcode': ['ov05Ma', 'un04No', 'pr03De', 'NW2 4BW'], 'other_links': [], 'year': [[None, None]], 'university': ['London', 'Lincoln', 'Reading', 'London'], 'degree': ['Business Administration'], 'major': [None], 'Date': [{'start_year': None, 'end_year': None}], 'Job_Title': ['Web Coordinator', 'Online Database Coordinator', 'Online Database Coordinator', 'Online Database Coordinator', 'Web Coordinator'], 'company': ['Carphonewarehouse', 'Carphonewarehouse', 'Escapade Limited'], 'skills': ['Marketing', 'Web Content'], 'edu_keyword': ['Education', 'Jan04-Dec05Master of Business Administration in  American World      ', 'Jan04-Dec05Master of Business Administration in  American World      ', '                                                 Campus              ', 'Sep96-May00Bachelor of Business Administration   University of       ', 'Sep96-May00Bachelor of Business Administration   University of       ', '                                                 Humberside          ', 'Computer skills:', 'MS Office (Word, Excel, PowerPoint, Access, Publisher), MS Project, Lotus', 'Notes, Adobe Photoshop, Dreamweaver, Visual Basic, Remedy, and Internet', 'Interests:', 'Interests:', 'and newspapers & enjoy travelling', '-----------------------', 'ZULFIQAR HASSAN', '26 Landau House, Chatsworth Rd,', '26 Landau House, Chatsworth Rd,', ''], 'work_keyword': ['Work Experience', 'May07To Date         Web Coordinator', 'May07To Date         Web Coordinator', 'Carphonewarehouse London', 'responsibilities includes ', 'Ensuring that all pricing special offers and promotions on the', 'website are up to date accurate and consistent with the commercial', 'direction', 'Managing the day to day requests from the commercial and marketing', 'teams to deliver and achieve tight deadlines', 'Implementing offers and content  including uploading testing', 'quality assuring and trouble shooting online campaigns', 'Maintaining internal relationships with commercial promotions', 'creative and marketing departments', 'Monitoring performance of offers and providing suggestion on future', 'offer setups', 'Apr06Apr07          Online Database Coordinator', 'Apr06Apr07          Online Database Coordinator', 'Managing the website content and assisting on the shop floor related tasks', 'Key responsibilities include ', 'Ensured all content on the website is accurate and updated and', 'modified accordingly']}
# --- 497.504940032959 seconds ---

# %%
exe = d['cv_name'].split(".")[1]

            print(exe)
            doc = ['DOC','doc','DOCX','docx']
            pdf = ['PDF','pdf']

            if not d['other_links']:
                other_mail = None
            else:
                other_mail = ", ".join(str(x) for x in d['other_links'])

            if exe in doc:
                param = (d['cv_name'],d['name'][0],None,d['email'][0],other_mail,d['phone'][0][0],d['zipcode'][0])
                #print(param)
            elif exe in pdf:
                param = (d['cv_name'],d['name'][0],None,d['email'][0],other_mail,d['phone'][0],d['zipcode'][0])
                #print(param)

            cnx = MySQLdb.connect(host = 'localhost',
                                         database = 'cv_parse',
                                         user = 'root',
                                         password = 'root', 
                                         compress = 1,
                                         cursorclass=MySQLdb.cursors.DictCursor)

            cursor = cnx.cursor()

            # Name

            qmarks = ', '.join(['%s'] * len(param))
            #print(qmarks)

            query = """INSERT INTO users
                                      (cv_name,firstname,lastname, e_mail,other_email, phone_number, location)
                                      VALUES 
                                      ( %s )""" %(qmarks)

            cursor.execute(query,param)
            cnx.commit()

            user_id = cursor.lastrowid
            print(user_id)
            print ("Record inserted successfully into python_users table")

            ek = ", ".join(str(x) for x in d['edu_keyword'])

            for i in range(0,len(d['university'])):
                par = (user_id, d['university'][0],None,d['year'][i][0],d['year'][i][1],d['degree'][0],ek)
                #print(par)

                qmarks = ', '.join(['%s'] * len(par))
                #print(qmarks)

                query = """INSERT INTO user_education
                                          (user_id,university_name,university_addr,edu_start_year,edu_end_year,
                                          edu_degree,edu_keywords)
                                          VALUES 
                                          ( %s )""" %(qmarks)

                #q = "INSERT INTO cv_parse_data (name,email,phone,zipcode) VALUES  (%s %s %s %s) "
                cursor.execute(query,par)
                cnx.commit()
                print ("Education Record inserted successfully into python_users table")


            wk = ", ".join(str(x) for x in d['work_keyword'] )
            sk = ", ".join(str(x) for x in d['skill_keyword'] )
            skill = ", ".join(str(x) for x in d['skills'] )

            cnx = MySQLdb.connect(host = 'localhost',
                                         database = 'cv_parse',
                                         user = 'root',
                                         password = 'root', 
                                         compress = 1,
                                         cursorclass=MySQLdb.cursors.DictCursor)

            cursor = cnx.cursor()

            #if len(d['company']) == len(d['Job_Title']) == len(d['Date']):
            for i in range(0,len(d['company'])):

                if i == 0:
                    p = (user_id,d['company'][i],d['Job_Title'][i],d['Date'][i]['start_year'],d['Date'][i]['end_year'],skill,wk,sk)
                else:  
                    try:
                        p = (user_id,d['company'][i],d['Job_Title'][i],d['Date'][i]['start_year'],d['Date'][i]['end_year'],skill,wk,sk)
                    except:
                        p = (user_id,d['company'][i],None,None,None,skill,wk,sk)




                #print(p)
                qmarks = ', '.join(['%s'] * len(p))
                #print(qmarks)

                query = """INSERT INTO user_experience
                                          (user_id,company_name,position_title,exp_start_year,exp_end_year,skills,
                                          work_keyword,skill_keyword)
                                          VALUES 
                                          ( %s )""" %(qmarks)

                #q = "INSERT INTO cv_parse_data (name,email,phone,zipcode) VALUES  (%s %s %s %s) "
                cursor.execute(query,p)
                cnx.commit()
                print ("work_experience Record inserted successfully into python_users table")

            print("--- %s seconds ---" % (time.time() - start_time))
    except:
        print("Not compitible file format")

# %%
exe = d['cv_name'].split(".")[1]

print(exe)
doc = ['DOC','doc','DOCX','docx']
pdf = ['PDF','pdf']

if not d['other_links']:
    other_mail = None
else:
    other_mail = ", ".join(str(x) for x in d['other_links'])

if exe in doc:
    param = (d['cv_name'],d['name'][0],None,d['email'][0],other_mail,d['phone'][0][0],d['zipcode'][0])
    #print(param)
elif exe in pdf:
    param = (d['cv_name'],d['name'][0],None,d['email'][0],other_mail,d['phone'][0],d['zipcode'][0])
    #print(param)

cnx = MySQLdb.connect(host = 'localhost',
                             database = 'cv_parse',
                             user = 'root',
                             password = 'root', 
                             compress = 1,
                             cursorclass=MySQLdb.cursors.DictCursor)

cursor = cnx.cursor()

# Name

qmarks = ', '.join(['%s'] * len(param))
#print(qmarks)

query = """INSERT INTO users
                          (cv_name,firstname,lastname, e_mail,other_email, phone_number, location)
                          VALUES 
                          ( %s )""" %(qmarks)

cursor.execute(query,param)
cnx.commit()

user_id = cursor.lastrowid
print(user_id)
print ("Record inserted successfully into python_users table")

ek = ", ".join(str(x) for x in d['edu_keyword'])

for i in range(0,len(d['university'])):
    par = (user_id, d['university'][0],None,d['year'][i][0],d['year'][i][1],d['degree'][0],ek)
    #print(par)

    qmarks = ', '.join(['%s'] * len(par))
    #print(qmarks)

    query = """INSERT INTO user_education
                              (user_id,university_name,university_addr,edu_start_year,edu_end_year,
                              edu_degree,edu_keywords)
                              VALUES 
                              ( %s )""" %(qmarks)

    #q = "INSERT INTO cv_parse_data (name,email,phone,zipcode) VALUES  (%s %s %s %s) "
    cursor.execute(query,par)
    cnx.commit()
    print ("Education Record inserted successfully into python_users table")


wk = ", ".join(str(x) for x in d['work_keyword'] )
sk = ", ".join(str(x) for x in d['skill_keyword'] )
skill = ", ".join(str(x) for x in d['skills'] )

cnx = MySQLdb.connect(host = 'localhost',
                             database = 'cv_parse',
                             user = 'root',
                             password = 'root', 
                             compress = 1,
                             cursorclass=MySQLdb.cursors.DictCursor)

cursor = cnx.cursor()

#if len(d['company']) == len(d['Job_Title']) == len(d['Date']):
for i in range(0,len(d['company'])):

    if i == 0:
        p = (user_id,d['company'][i],d['Job_Title'][i],d['Date'][i]['start_year'],d['Date'][i]['end_year'],skill,wk,sk)
    else:  
        try:
            p = (user_id,d['company'][i],d['Job_Title'][i],d['Date'][i]['start_year'],d['Date'][i]['end_year'],skill,wk,sk)
        except:
            p = (user_id,d['company'][i],None,None,None,skill,wk,sk)




    #print(p)
    qmarks = ', '.join(['%s'] * len(p))
    #print(qmarks)

    query = """INSERT INTO user_experience
                              (user_id,company_name,position_title,exp_start_year,exp_end_year,skills,
                              work_keyword,skill_keyword)
                              VALUES 
                              ( %s )""" %(qmarks)

    #q = "INSERT INTO cv_parse_data (name,email,phone,zipcode) VALUES  (%s %s %s %s) "
    cursor.execute(query,p)
    cnx.commit()
    print ("work_experience Record inserted successfully into python_users table")

# %%
import nbimporter
import import_ipynb
from importlib import reload
import cv_parsing_main_class as main
import MySQLdb
import MySQLdb.cursors
import requests
import pandas as pd
import numpy as np


reload(main)

import os

import time
start_time = time.time()



#path = '/Users/imac086/Documents/premal/projects_Quix/CV_parsing/final_cv_parsing_code/cv_data'
#for filename in os.listdir(path):
#    try:
#        print(filename)
#        fn = filename.split(".")[1]
#        print(fn)
#        exten = ['DOC','doc','DOCX','docx','PDF','pdf']

#        if fn in exten:
#            """SQL Query used"""
details = main.parse_all_details('ZoeCaseyJan07.doc')
d = details.info()

if not d['name']:
    d['name'].append(None)
if not d['email']:
    d['email'].append(None)
if not d['phone']:
    d['phone'].append([None])
if not d['zipcode']:
    d['zipcode'].append(None)
if not d['year']:
    y = [None,None]
    d['year'].append(y)
if not d['university']:
    d['university'].append(None)
if not d['degree']:
    d['degree'].append(None)
if not d['major']:
    d['major'].append(None)
if not d['Date']:
    y = {'start_year':None,'end_year':None}
    d['Date'].append(y)
if not d['Job_Title']:
    d['Job_Title'].append(None)
if not d['company']:
    d['company'].append(None)
if not d['skill_keyword']:
    d['skill_keyword'].append(None)

print("===== Final Output ===========")
print(d)

exe = d['cv_name'].split(".")[1]

print(exe)
doc = ['DOC','doc','DOCX','docx']
pdf = ['PDF','pdf']

if not d['other_links']:
    other_mail = None
else:
    other_mail = ", ".join(str(x) for x in d['other_links'])

if exe in doc:
    param = (d['cv_name'],d['name'][0],None,d['email'][0],other_mail,d['phone'][0][0],d['zipcode'][0])
    #print(param)
elif exe in pdf:
    param = (d['cv_name'],d['name'][0],None,d['email'][0],other_mail,d['phone'][0],d['zipcode'][0])
    #print(param)

cnx = MySQLdb.connect(host = 'localhost',
                             database = 'cv_parse',
                             user = 'root',
                             password = 'root', 
                             compress = 1,
                             cursorclass=MySQLdb.cursors.DictCursor)

cursor = cnx.cursor()

# Name

qmarks = ', '.join(['%s'] * len(param))
#print(qmarks)

query = """INSERT INTO users
                          (cv_name,firstname,lastname, e_mail,other_email, phone_number, location)
                          VALUES 
                          ( %s )""" %(qmarks)

cursor.execute(query,param)
cnx.commit()

user_id = cursor.lastrowid
print(user_id)
print ("Record inserted successfully into python_users table")

ek = ", ".join(str(x) for x in d['edu_keyword'])

for i in range(0,len(d['university'])):
    par = (user_id, d['university'][0],None,d['year'][i][0],d['year'][i][1],d['degree'][0],ek)
    #print(par)

    qmarks = ', '.join(['%s'] * len(par))
    #print(qmarks)

    query = """INSERT INTO user_education
                              (user_id,university_name,university_addr,edu_start_year,edu_end_year,
                              edu_degree,edu_keywords)
                              VALUES 
                              ( %s )""" %(qmarks)

    #q = "INSERT INTO cv_parse_data (name,email,phone,zipcode) VALUES  (%s %s %s %s) "
    cursor.execute(query,par)
    cnx.commit()
    print ("Education Record inserted successfully into python_users table")


wk = ", ".join(str(x) for x in d['work_keyword'] )
sk = ", ".join(str(x) for x in d['skill_keyword'] )
skill = ", ".join(str(x) for x in d['skills'] )

cnx = MySQLdb.connect(host = 'localhost',
                             database = 'cv_parse',
                             user = 'root',
                             password = 'root', 
                             compress = 1,
                             cursorclass=MySQLdb.cursors.DictCursor)

cursor = cnx.cursor()

#if len(d['company']) == len(d['Job_Title']) == len(d['Date']):
for i in range(0,len(d['company'])):

    if i == 0:
        p = (user_id,d['company'][i],d['Job_Title'][i],d['Date'][i]['start_year'],d['Date'][i]['end_year'],skill,wk,sk)
    else:  
        try:
            p = (user_id,d['company'][i],d['Job_Title'][i],d['Date'][i]['start_year'],d['Date'][i]['end_year'],skill,wk,sk)
        except:
            p = (user_id,d['company'][i],None,None,None,skill,wk,sk)




    #print(p)
    qmarks = ', '.join(['%s'] * len(p))
    #print(qmarks)

    query = """INSERT INTO user_experience
                              (user_id,company_name,position_title,exp_start_year,exp_end_year,skills,
                              work_keyword,skill_keyword)
                              VALUES 
                              ( %s )""" %(qmarks)

    #q = "INSERT INTO cv_parse_data (name,email,phone,zipcode) VALUES  (%s %s %s %s) "
    cursor.execute(query,p)
    cnx.commit()
    print ("work_experience Record inserted successfully into python_users table")


print("--- %s seconds ---" % (time.time() - start_time))
#    except:
#        print("Not compitible file format")
# Out:
# Importing Jupyter notebook from cv_parsing_main_class.ipynb
# Accounting
# Parse Name from DOC ====== ['Advert']
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ********Title First function**********
# {'cv_name': 'ZoeCaseyJan07.doc', 'name': ['Advert'], 'email': ['shaun.casey4@btinternet.com'], 'phone': [['01980 843944           ', '07963 641053                 '], ['2001-2002    '], ['1998  99    '], ['1994  96    '], ['1988  94    ']], 'zipcode': ['HA7 2RS'], 'other_links': [], 'year': [], 'university': [], 'degree': [], 'major': [], 'skills': [], 'Date': [{'start_year': 'January 2007', 'end_year': 'Present'}, {'start_year': 'October 2003', 'end_year': 'Present'}, {'start_year': '2006', 'end_year': 'Present'}, {'start_year': '2002', 'end_year': 'Present'}, {'start_year': '2003', 'end_year': 'Present'}, {'start_year': 'March 2001', 'end_year': 'Present'}, {'start_year': '2002', 'end_year': 'Present'}, {'start_year': '1999', 'end_year': 'Present'}, {'start_year': '2000', 'end_year': 'Present'}], 'Job_Title': ['Manager', 'Partner', 'Director', 'Director', 'Manager', 'Manager', 'Manager', 'HR', 'Manager', 'HR', 'Manager', 'Partner', 'ACTIVE', 'HR', 'Employee Relations', 'Manager', 'Manager', 'Manager', 'Administrator'], 'company': ['Me', 'Human Resources', 'Human Resources', 'Human Resources', 'Human Resources', 'Human Resources'], 'edu_keyword': ['|Qualification|                                                             |', '|s            |                                                             |', '|             |                                                             |', '|2004         |Level A & B Certificates of Competence in Occupational       |', '|             |Testing                                                      |', '|             |The Test Agency, Oxford                                      |', '|             |                                                             |', '|             |University of Wolverhampton                                  |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|1998  99    |BA (Hons) Business Administration                            |', '|             |Degree Class 2:1                                             |', '|             |University of Wolverhampton                                  |', '|             |                                                             |', '|1996 - 98    |HND Business and Finance                                     |', '|             |Tamworth and Lichfield College, Staffordshire                |', '|             |                                                             |', '|             |BTEC National Diploma in Fashion Design                      |', '|1994  96    |North Warwickshire and Hinckley College                      |', '|             |                                                             |', '|1988  94    |8 GCSEs                                                     |', '|             |Queen Elizabeth Mercian School, Tamworth, Staffordshire      |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                            |                                |', '|             |                            |                                |', '|             |                            |                                |', '|             |                            |                                |', '|             |                                                             |', '| ...
# ===== Final Output ===========
# {'cv_name': 'ZoeCaseyJan07.doc', 'name': ['Advert'], 'email': ['shaun.casey4@btinternet.com'], 'phone': [['01980 843944           ', '07963 641053                 '], ['2001-2002    '], ['1998  99    '], ['1994  96    '], ['1988  94    ']], 'zipcode': ['HA7 2RS'], 'other_links': [], 'year': [[None, None]], 'university': [None], 'degree': [None], 'major': [None], 'skills': [], 'Date': [{'start_year': 'January 2007', 'end_year': 'Present'}, {'start_year': 'October 2003', 'end_year': 'Present'}, {'start_year': '2006', 'end_year': 'Present'}, {'start_year': '2002', 'end_year': 'Present'}, {'start_year': '2003', 'end_year': 'Present'}, {'start_year': 'March 2001', 'end_year': 'Present'}, {'start_year': '2002', 'end_year': 'Present'}, {'start_year': '1999', 'end_year': 'Present'}, {'start_year': '2000', 'end_year': 'Present'}], 'Job_Title': ['Manager', 'Partner', 'Director', 'Director', 'Manager', 'Manager', 'Manager', 'HR', 'Manager', 'HR', 'Manager', 'Partner', 'ACTIVE', 'HR', 'Employee Relations', 'Manager', 'Manager', 'Manager', 'Administrator'], 'company': ['Me', 'Human Resources', 'Human Resources', 'Human Resources', 'Human Resources', 'Human Resources'], 'edu_keyword': ['|Qualification|                                                             |', '|s            |                                                             |', '|             |                                                             |', '|2004         |Level A & B Certificates of Competence in Occupational       |', '|             |Testing                                                      |', '|             |The Test Agency, Oxford                                      |', '|             |                                                             |', '|             |University of Wolverhampton                                  |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|1998  99    |BA (Hons) Business Administration                            |', '|             |Degree Class 2:1                                             |', '|             |University of Wolverhampton                                  |', '|             |                                                             |', '|1996 - 98    |HND Business and Finance                                     |', '|             |Tamworth and Lichfield College, Staffordshire                |', '|             |                                                             |', '|             |BTEC National Diploma in Fashion Design                      |', '|1994  96    |North Warwickshire and Hinckley College                      |', '|             |                                                             |', '|1988  94    |8 GCSEs                                                     |', '|             |Queen Elizabeth Mercian School, Tamworth, Staffordshire      |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                                                             |', '|             |                            |                                |', '|             |                            |                                |', '|             |                            |                                |', '|             |                            |                                |', '|             |                                            ...
# doc
# 29003
# Record inserted successfully into python_users table
# Education Record inserted successfully into python_users table
# work_experience Record inserted successfully into python_users table
# work_experience Record inserted successfully into python_users table
# work_experience Record inserted successfully into python_users table
# work_experience Record inserted successfully into python_users table
# work_experience Record inserted successfully into python_users table
# work_experience Record inserted successfully into python_users table
# --- 517.5352311134338 seconds ---

# %%
s = [('March', 'NNP')]
print(s[0][0])
# Out:
# March

# %%
s[0][0] = "ab"
print(s[0][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b0a4aac47972> in <module>()
# ----> 1 s[0][0] = "ab"
#       2 print(s[0][0])
#
# TypeError: 'tuple' object does not support item assignment
